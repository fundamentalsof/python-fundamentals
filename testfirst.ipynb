# %%
print("hello world")
# Out:
# hello world

# %%
a = 1000

# %%
a += 100
print(a)
# Out:
# 1100

# %% [markdown]
# # Basic Data types

# %%
1
# Out:
# 1

# %%
1.0
# Out:
# 1.0

# %%
True
# Out:
# True

# %%
False
# Out:
# False

# %%
0.1
# Out:
# 0.1

# %%
format(0.1, '0.25f')
# Out:
# '0.1000000000000000055511151'

# %%
0.1 + 0.1 + 0.1 == 0.3
# Out:
# False

# %% [markdown]
# # OBJECTS

# %%
class Foo:
    def setbar(self, amount):
        self.amount = amount

    def getbar(self):
        return self.amount

# %%
foo = Foo()
foo.setbar(1000)
print(foo.getbar())
print(foo.amount)
# Out:
# 1000
# 1000

# %%
apy=0.1

# %%
apy='0.1'

# %%
print( float(apy))
# Out:
# 0.1

# %% [markdown]
# # Variables

# %%
a=100
a=100.0

# %%
b= a+1
print(b)
# Out:
# 101.0

# %%
test=b
_test=b
TEST=b

# %%
float = 199.5

# %%
del float
c =float(a)

# %% [markdown]
# # Arithmetic Operators

# %%
-1
# Out:
# -1

# %%
2**4
# Out:
# 16

# %%
2**-3
# Out:
# 0.125

# %%
(-4)**2
# Out:
# 16

# %%
(-4) ** (-2)
# Out:
# 0.0625

# %%
c = (-4) ** (-0.5)

# %%
type(c)
# Out:
# complex

# %%
print(c.imag)
print(c.real)
print(c)
# Out:
# -0.5
# 3.061616997868383e-17
# (3.061616997868383e-17-0.5j)
